# %% [markdown]
# <a href="https://colab.research.google.com/github/mukeshyadav4747/ML/blob/main/DecisionTree_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DecisionTree Model
#
# (a). Gini Index
# (b). Changes in Entropy

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/covid_toy.csv")
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df = df.dropna()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['gender'] = lb.fit_transform(df['gender'])
df['cough'] = lb.fit_transform(df['cough'])
df['city'] = lb.fit_transform(df['city'])
df['has_covid'] = lb.fit_transform(df['has_covid'])

# %%
df.head(3)
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0
# 1   27       1  100.0      0     1          1
# 2   42       1  101.0      0     1          0

# %%
x = df.drop(columns=['has_covid'])
y = df['has_covid']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size =0.2,random_state=42)

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.4444444444444444

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.4444444444444444

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Fine Tuning

param_grid = {'max_depth':[10,20,30,None], 'min_samples_split':[2,5,10],
              'min_samples_leaf':[1,2,4]}

# %%
dtree_clf = DecisionTreeClassifier(random_state= 42)

# %%
grid_search = GridSearchCV(estimator= dtree_clf, param_grid=param_grid, cv=5,n_jobs= -1,
                        verbose =2, scoring= 'neg_mean_squared_error'  )

# %%
grid_search.fit(x_train,y_train)
best_dtree_reg = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits

# %%
best_dtree_reg
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=4, random_state=42)

# %%
y_pred = best_dtree_reg.predict(x_test)

# %%
ac = accuracy_score(y_test,y_pred)

# %%
best_params = grid_search.best_params_
print(f'Best parameter: {best_params}')
# Out:
# Best parameter: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2}

# %%
ac
# Out:
# 0.3888888888888889

# %%
df.corr()
# Out:
#                 age    gender     fever     cough      city  has_covid
# age        1.000000 -0.007032 -0.017828  0.003323  0.023030  -0.052940
# gender    -0.007032  1.000000  0.028857 -0.197674 -0.145659   0.082656
# fever     -0.017828  0.028857  1.000000 -0.145178 -0.081137  -0.188127
# cough      0.003323 -0.197674 -0.145178  1.000000 -0.063151  -0.136936
# city       0.023030 -0.145659 -0.081137 -0.063151  1.000000   0.055240
# has_covid -0.052940  0.082656 -0.188127 -0.136936  0.055240   1.000000
