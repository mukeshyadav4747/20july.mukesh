# %% [markdown]
# <a href="https://colab.research.google.com/github/mukeshyadav4747/ML/blob/main/Logistic_Regression_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LogisticRegression ----> Target data is categorical

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/covid_toy.csv")
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['gender']= lb.fit_transform(df['gender'])
df['cough']= lb.fit_transform(df['cough'])
df['city']= lb.fit_transform(df['city'])
df['has_covid']= lb.fit_transform(df['has_covid'])

# %%
df.head(3)
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0
# 1   27       1  100.0      0     1          1
# 2   42       1  101.0      0     1          0

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df = df.dropna()

# %%
df.head(3)
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0
# 1   27       1  100.0      0     1          1
# 2   42       1  101.0      0     1          0

# %%
x = df.drop(columns=['has_covid'])
y = df['has_covid']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test,y_train, y_test = train_test_split(x,y,test_size =0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.4444444444444444

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[6, 2],
#        [8, 2]])

# %%
param_grid =[{'penalty':['l1','l2','elasticnet','none'], 'c': np.logspace(-4,4,20),'solver':['lbfgs','newton-cg','liblinear','sag','saga'],
              'max_iter':[100,1000,2500,5000]}]

# %%
from sklearn.model_selection import GridSearchCV

# %%
clf = GridSearchCV(lr, param_grid= param_grid, cv =3, verbose= True, n_jobs=-1)
clf
# Out:
# GridSearchCV(cv=3, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid=[{'c': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                           'max_iter': [100, 1000, 2500, 5000],
#                           'penalty': ['l1', 'l2', 'elasticnet', 'none'],
#                           'solver': ['lbfgs', 'newton-cg', 'liblinear', 'sag',
#                                      'saga']}],
#              verbose=True)

# %%
best_clf = clf.fit(x,y)
best_clf.best_estimator_
# Out:
# Fitting 3 folds for each of 1600 candidates, totalling 4800 fits
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/joblib/externals/loky/process_executor.py", line 463, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/joblib/parallel.py", line 598, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/joblib/parallel.py", line 598, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
print(f'Accuracy- : {best_clf.score(x,y):.3f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-24836b50c5f1> in <cell line: 0>()
# ----> 1 print(f'Accuracy- : {best_clf.score(x,y):.3f}')
#
# NameError: name 'best_clf' is not defined

# %%
# [tp,  fp]
#  [fn, tn]
# tp = true positive
# tn = true negative
# fp = false positive
# fn = false negative

# %%
from sklearn.model_selection import GridSearchCV

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.4444444444444444

# %%
# LogisticRegresiion ----->  Target data ---> categorical ---> Backend activation function
# Sigmoid Activation function ----> probality (0-1)
# threshold_value = 0.5 or 1/2
# if value>0.5
#      return 1
# else:
#      return 0

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.4444444444444444
